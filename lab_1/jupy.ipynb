# %% [markdown]
# Antoni Pawłowicz 191733
#
# <div align="center">
# <em>
# METODY INTERAKCJI CZŁOWIEK MASZYNA</br></br>
# Laboratoria 1</br>
# Wprowadzenie do python, QT C++ i Flutter (Dart)
# </em>

# %% [markdown]
# ### _Zadanie 1_
# Po uruchomieniu Jupyter Notebook zapoznaj się z interfejsem oprogramowania.
# Napisz i scharakteryzuj jakie typy mogą przyjmować komórki w Jupyter Notebook.

# %%
a = 'Hello'
b = 'World'
c = f'{a} {b} !!!'

c
# Out:
# 'Hello World !!!'

# %% [markdown]
# # Code block
# ## what for
# The code block if for writing and executing code
#
# # Markdown block
# ## what for
# The markdown block is for writing stuff. It uses latex synthax for equations:
#
# dollar-sign W = (X^TX)^{-1}X^TY dollar-sign
#
# $W = (X^TX)^{-1}X^TY$

# %% [markdown]
# ### _Zadanie 2_
# Napisz funkcję realizującą operację modulo dwóch liczb.

# %%
def modulo(a,b):
    full = a // b
    mod = a % b
    return f'the nums {a} {b} are divisible in a way: a = {full} * b + {mod}'

modulo(7,2)
# Out:
# 'the nums 7 2 are divisible in a way: a = 3 * b + 1'

# %% [markdown]
# ### _Zadanie 3_
# Wykorzystując bibliotekę opencv (cv2) stwórz program, który połączy się z
# kamerą, przekaże każdą przechwyconą klatkę do osobnej funkcji, która wykryje na niej
# twarz i ją zaznaczy oraz wyświetli tak przekształcony obraz z kamery.

# %%
import cv2
import matplotlib.pyplot as plt


cam = cv2.VideoCapture('/home/anthonyp57/VSCode_projects/MICM_2025/lab_3/man_vid.mp4') # 0 for camera

while(True):
    ret, frame = cam.read()

    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(frame, 1.3, 5)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    frame = cv2.cvtColor(frame, cv2.COLOR_GRAY2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(frame)
    plt.show()

    # cv2.imshow('frame',frame)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

    break # to exit after 1 frame

# %% [markdown]
# ### _Zadanie 4_
# Stwórz kolejną funkcję, która odwraca kolory obrazu z kamery i takie obrazy
# wyświetla (na żywo).

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

cam = cv2.VideoCapture('/home/anthonyp57/VSCode_projects/MICM_2025/lab_3/man_vid.mp4')

while(True):
    ret, frame = cam.read()

    frame = 255 - np.array(frame)

    plt.figure(figsize=(6, 6))
    plt.imshow(frame)
    plt.show()

    # cv2.imshow('frame',frame)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

    break # to exit after 1 frame

# %% [markdown]
# ### _Zadanie 5_
# Zmodyfikuj program tak, żeby pozwalał na wykonanie operacji modulo
# dwóch liczb podanych przez użytkownika. W tym celu można wykorzystać widget typu
# „line edit” (osobny widget dla pierwszej i drugiej liczby).

# %%
void MainWindow::on_pushButton_clicked()
{
    double a = ui->lineEdit->text().toDouble();
    double b = ui->lineEdit_2->text().toDouble();

    double result = fmod(a, b);

    ui->label->setText(QString::number(result));
}

# %% [markdown]
# ### _Zadanie 6_
# Zmodyfikuj powyższy kod tak, żeby funkcja „_myOnClickFunction()”
# realizowała operację dodawania dwóch liczb przekazywanych za pośrednictwem
# widgetów „TextField”

# %%
import 'package:flutter/material.dart';

void main() {
  runApp(MyApp());
}

class MyApp extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    return MaterialApp(
      title: 'Hellow world',
      theme: ThemeData(
        primarySwatch: Colors.blue,
        visualDensity: VisualDensity.adaptivePlatformDensity,
      ),
      home: MyHomePage(title: 'Hello wordl app'),
    );
  }
}

class MyHomePage extends StatefulWidget {
  MyHomePage({Key? key, required this.title}) : super(key: key);
  final String title;
  @override
  _MyHomePageState createState() => _MyHomePageState();
}

class _MyHomePageState extends State<MyHomePage> {
  String _my_string = ""; // This will store the result of addition
  int _a = 0; // First number
  int _b = 0; // Second number

  void _myOnClickFunction() {
    setState(() {
      _my_string = (_a + _b).toString(); // Add numbers and store the result
    });
  }

  @override
  Widget build(BuildContext context) {
    return Scaffold(
      appBar: AppBar(
        title: Text(widget.title),
      ),
      body: Center(
        child: Column(
          mainAxisAlignment: MainAxisAlignment.center,
          children: <Widget>[
            TextField(
              onChanged: (value) => _a = int.tryParse(value) ?? 0, // Get the first number
              decoration: InputDecoration(
                border: OutlineInputBorder(),
                labelText: 'A',
              ),
            ),
            TextField(
              onChanged: (value) => _b = int.tryParse(value) ?? 0, // Get the second number
              decoration: InputDecoration(
                border: OutlineInputBorder(),
                labelText: 'B',
              ),
            ),
            Text(
              '$_my_string', // Display the result
              style: Theme.of(context).textTheme.headline4,
            ),
            OutlineButton(
              child: new Text("Click me"), // Button to perform addition
              onPressed: _myOnClickFunction,
            )
          ],
        ),
      ),
    );
  }
}
